# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import datetime
from matplotlib.colors import LinearSegmentedColormap

if Path.home().name == "nikolaibeckjensen":
    DATA_ROOT = Path.home() / "Library" / "CloudStorage" / "OneDrive-DanmarksTekniskeUniversitet" / "Virk2Vec" / "data"
elif Path.home().name == "annabramslow":
    DATA_ROOT = Path.home() / "Library" / "CloudStorage" / "OneDrive-DanmarksTekniskeUniversitet(2)" / "Virk2Vec" / "data"

save_path = r'/Users/annabramslow/Desktop/Figurer - Deskriptiv Analyse'

# %%
plt.rcParams["grid.linestyle"] =  ":"
plt.rcParams["axes.edgecolor"] = "grey"
plt.rcParams["axes.linewidth"] = 0.7

#font 
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'

# %% [markdown]
# ## Count Sentences

# %%
global_folder = DATA_ROOT / "processed" / "corpus" / "global_set" / "sentences" / "train"

# %%
#read all parquet files in global_folder
global_data = pd.concat([pd.read_parquet(file) for file in global_folder.glob("*.parquet")])

# %%
#remove columns CURRENT_ASSETS, CASH_AND_CASH_EQUIVALENTS, SHORT_TERM_LIABILITIES
global_data = global_data.drop(columns = ["CURRENT_ASSETS", "CASH_AND_CASH_EQUIVALENTS", "SHORT_TERM_LIABILITIES"])

# %%
#create list of all unique CVR numbers, which are the index values
CVR_list = global_data.index.values
CVR_list = list(dict.fromkeys(CVR_list))

# %%
#number of unique CVR numbers in the global training set
print("Number of unique CVR numbers in the global training set: ", len(CVR_list))
# Out:
# Number of unique CVR numbers in the global training set:  287631

# %%
#remove sentences after threshold (i.e. sentences in 2022 and 2023)
global_data= global_data[~global_data["AFTER_THRESHOLD"]]

# %%
global_data
# Out:
#           FROM_DATE                                           SENTENCE  \
# CVR
# 40975470       2521                          ACT_OPEN IND_7732 MUN_370
# 40975470       2521                                       CSTAT_ACTIVE
# 40975470       2555                       LEADER_DIRECTOR EXPERIENCE_3
# 40975470       2769  CTYPE_APS IND_7732 CSTAT_ACTIVE MUN_340 EMPLOY...
# 40975470       2800  CTYPE_APS IND_7732 CSTAT_ACTIVE MUN_340 EMPLOY...
# ...             ...                                                ...
# 33920717       3195  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3220  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 PROFIT_...
# 33920717       3226  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3256  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3286   LEADER_BOARD EXPERIENCE_3 LEADER_CEO EXPERIEN...
#
#          FOUNDING_DATE  AFTER_THRESHOLD   AGE
# CVR
# 40975470    2019-11-27            False   0.0
# 40975470    2019-11-27            False   0.0
# 40975470    2019-11-27            False  -1.0
# 40975470    2019-11-27            False   0.0
# 40975470    2019-11-27            False   0.0
# ...                ...              ...   ...
# 33920717    1971-03-05            False  50.0
# 33920717    1971-03-05            False  50.0
# 33920717    1971-03-05            False  50.0
# 33920717    1971-03-05            False  50.0
# 33920717    1971-03-05            False  49.0
#
# [10194841 rows x 5 columns]

# %% [markdown]
# ### Production Units

# %%
#punit path
punit_folder = DATA_ROOT / "processed" / "sources" / "punits" / "tokenized"

# %%
#read all parquet files in punit_folder
punit_data = pd.concat([pd.read_parquet(file) for file in punit_folder.glob("*.parquet")])

# %%
#only keep the rows in punit_data that have a CVR number that is in CVR_list
punit_data = punit_data[punit_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
punit_data["FROM_DATE"] = pd.to_datetime(punit_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
punit_data = punit_data[punit_data["FROM_DATE"] < threshold]

# %%
punit_data
# Out:
#           FROM_DATE    ACTION MUNICIPALITY  INDUSTRY
# CVR
# 40173048 2019-01-15  ACT_OPEN      MUN_169  IND_4333
# 40173064 2019-01-11  ACT_OPEN      MUN_479  IND_1812
# 40173099 2019-01-15  ACT_OPEN      MUN_201  IND_6202
# 40173129 2019-01-15  ACT_OPEN      MUN_791  IND_6420
# 40173137 2019-01-15  ACT_OPEN      MUN_269  IND_4339
# ...             ...       ...          ...       ...
# 37133574 2015-10-05  ACT_OPEN      MUN_265  IND_9999
# 37133698 2015-10-01  ACT_OPEN      MUN_230  IND_5829
# 37133728 2015-09-22  ACT_OPEN      MUN_430  IND_4531
# 37133736 2015-10-05  ACT_OPEN      MUN_751  IND_6420
# 37133744 2015-09-28  ACT_OPEN      MUN_751  IND_6420
#
# [244916 rows x 4 columns]

# %%
#print number of sentences in the punit data 
print("Number of sentences in the status data: ", punit_data.shape[0])
# Out:
# Number of sentences in the status data:  244916

# %% [markdown]
# ### Company Status

# %%
#status path
status_folder = DATA_ROOT / "processed" / "sources" / "status" / "tokenized"

# %%
#read all parquet files in status_folder
status_data = pd.concat([pd.read_parquet(file) for file in status_folder.glob("*.parquet")])

# %%
#only keep the rows in status_data that have a CVR number that is in CVR_list
status_data = status_data[status_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
status_data["FROM_DATE"] = pd.to_datetime(status_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
status_data = status_data[status_data["FROM_DATE"] < threshold]

# %%
status_data
# Out:
#           FROM_DATE               COMPANY_STATUS
# CVR
# 40287337 2019-02-25                 CSTAT_ACTIVE
# 40287531 2019-02-25                 CSTAT_ACTIVE
# 40287787 2019-02-25                 CSTAT_ACTIVE
# 40287957 2019-02-24                 CSTAT_ACTIVE
# 40287981 2019-02-25                 CSTAT_ACTIVE
# ...             ...                          ...
# 36049898 2017-09-18  CSTAT_DISSOLVED_DECLARATION
# 36049944 2014-07-11                 CSTAT_ACTIVE
# 36049979 2014-07-15                 CSTAT_ACTIVE
# 36049995 2014-07-15                 CSTAT_ACTIVE
# 36049995 2017-04-04  CSTAT_DISSOLVED_DECLARATION
#
# [267726 rows x 2 columns]

# %%
#print number of sentences in the status data (rows)
print("Number of sentences in the status data: ", status_data.shape[0])
# Out:
# Number of sentences in the status data:  267726

# %% [markdown]
# ### Raising Capital

# %%
#capital path
capital_folder = DATA_ROOT / "processed" / "sources" / "capital" / "tokenized"

# %%
#read all parquet files in capital_folder
capital_data = pd.concat([pd.read_parquet(file) for file in capital_folder.glob("*.parquet")])

# %%
#only keep the rows in capital_data that have a CVR number that is in CVR_list
capital_data = capital_data[capital_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
capital_data["FROM_DATE"] = pd.to_datetime(capital_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
capital_data = capital_data[capital_data["FROM_DATE"] < threshold]

# %%
capital_data
# Out:
#           FROM_DATE PAYMENT_TYPE          RATE    INVESTMENT
# CVR
# 39638754 2018-06-21     PAY_CASH  4.624167e+04  2.219600e+07
# 39638754 2018-06-21     PAY_CASH  2.270000e+04  2.315400e+07
# 39639157 2018-08-31     PAY_CASH  2.049072e+08  2.049072e+08
# 39639548 2021-10-15     PAY_CASH  1.000000e+02  4.000000e+04
# 39639785 2021-02-22     PAY_CASH  1.000000e+02  3.999900e+04
# ...             ...          ...           ...           ...
# 37167983 2021-10-12     PAY_CASH  1.000000e+02  4.000000e+04
# 37168025 2021-10-12     PAY_CASH  1.000000e+02  4.000000e+04
# 37169102 2021-07-15   PAY_MERGER  1.000000e+02  3.999900e+04
# 37169285 2016-02-22     PAY_CASH  1.045535e+07  1.045535e+08
# 37169285 2020-01-29     PAY_DEBT  8.621724e+05  8.621724e+06
#
# [57280 rows x 4 columns]

# %%
#print number of sentences in the capital data (rows)
print("Number of sentences in the capital data: ", capital_data.shape[0])
# Out:
# Number of sentences in the capital data:  57280

# %%
capital_data.PAYMENT_TYPE.value_counts()
# Out:
# PAY_CASH      33314
# PAY_PROFIT    11561
# PAY_DEBT       9052
# PAY_ASSETS     1763
# PAY_MERGER     1481
# Name: PAYMENT_TYPE, dtype: int64

# %% [markdown]
# ### Leadership

# %%
#leadership path
leadership_folder = DATA_ROOT / "processed" / "sources" / "leadership" / "tokenized"

# %%
#read all parquet files in leadership_folder
leadership_data = pd.concat([pd.read_parquet(file) for file in leadership_folder.glob("*.parquet")])

# %%
#only keep the rows in leadership_data that have a CVR number that is in CVR_list
leadership_data = leadership_data[leadership_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
leadership_data["FROM_DATE"] = pd.to_datetime(leadership_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
leadership_data = leadership_data[leadership_data["FROM_DATE"] < threshold]

# %%
leadership_data
# Out:
#           FROM_DATE PARTICIPANT_TYPE  EXPERIENCE
# CVR
# 30723910 2013-12-31  LEADER_DIRECTOR           6
# 30723910 2014-12-31  LEADER_DIRECTOR           7
# 30723910 2015-12-31  LEADER_DIRECTOR           8
# 30723910 2016-12-31  LEADER_DIRECTOR           9
# 30723910 2017-12-31  LEADER_DIRECTOR          10
# ...             ...              ...         ...
# 41024135 2019-12-31       LEADER_CEO           0
# 41024135 2020-12-31       LEADER_CEO           1
# 41024135 2021-12-31       LEADER_CEO           2
# 41024143 2020-12-31  LEADER_DIRECTOR           0
# 41024143 2021-12-31  LEADER_DIRECTOR           1
#
# [3234672 rows x 3 columns]

# %%
#compute number of unique combinations of CVR number and FROM_DATE in the leadership data
print("Number of unique combinations of CVR number and FROM_DATE in the leadership data: ", leadership_data.groupby(["CVR", "FROM_DATE"]).size().shape[0])
# Out:
# Number of unique combinations of CVR number and FROM_DATE in the leadership data:  1724931

# %% [markdown]
# ### Ownership

# %%
#ownership path
ownership_folder = DATA_ROOT / "processed" / "sources" / "ownership" / "tokenized"

# %%
#read all parquet files in ownership_folder
ownership_data = pd.concat([pd.read_parquet(file) for file in ownership_folder.glob("*.parquet")])

# %%
#only keep the rows in ownership_data that have a CVR number that is in CVR_list
ownership_data = ownership_data[ownership_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
ownership_data["FROM_DATE"] = pd.to_datetime(ownership_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
ownership_data = ownership_data[ownership_data["FROM_DATE"] < threshold]

# %%
ownership_data
# Out:
#           FROM_DATE OWNER_TYPE         SHARE  INDUSTRY  EMPLOYEE_COUNT  \
# CVR
# 10000157 2018-11-28   OTYP_EXT   SHARE_50_60  IND_9312            10.0
# 10000157 2019-10-24   OTYP_EXT   SHARE_50_60  IND_2599            10.0
# 10000157 2020-10-29   OTYP_EXT  SHARE_90_100  IND_8690             NaN
# 10000157 2021-06-09   OTYP_EXT   SHARE_20_30  IND_6499             NaN
# 10000157 2021-08-10   OTYP_EXT  SHARE_90_100  IND_4643            30.0
# ...             ...        ...           ...       ...             ...
# 89990114 2021-04-01   OTYP_INT   SHARE_20_30  IND_6430             1.0
# 89998719 2015-09-23   OTYP_EXT  SHARE_90_100  IND_5110             4.0
# 89998719 2020-11-30   OTYP_INT  SHARE_90_100  IND_6420             NaN
# 89998719 2021-01-01   OTYP_EXT   SHARE_50_60  IND_7912            12.0
# 89998719 2021-02-01   OTYP_EXT   SHARE_20_30  IND_6499             NaN
#
#                ASSETS
# CVR
# 10000157    2584696.0
# 10000157   12162243.0
# 10000157    8478372.0
# 10000157    4468213.0
# 10000157  192736000.0
# ...               ...
# 89990114    9119497.0
# 89998719   10761539.0
# 89998719   13722000.0
# 89998719  150502000.0
# 89998719   13041827.0
#
# [403202 rows x 6 columns]

# %%
#compute number of sentences in the ownership data
print("Number of sentences in the ownership data: ", ownership_data.shape[0])
# Out:
# Number of sentences in the ownership data:  403202

# %% [markdown]
# ### Annual Reports

# %%
#financials path
financials_folder = DATA_ROOT / "processed" / "sources" / "financials" / "tokenized"

# %%
#read all parquet files in financials_folder
financials_data = pd.concat([pd.read_parquet(file) for file in financials_folder.glob("*.parquet")])

# %%
#only keep the rows in financials_data that have a CVR number that is in CVR_list
financials_data = financials_data[financials_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
financials_data["FROM_DATE"] = pd.to_datetime(financials_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
financials_data = financials_data[financials_data["FROM_DATE"] < threshold]

# %%
financials_data
# Out:
#           FROM_DATE COMPANY_TYPE  INDUSTRY COMPANY_STATUS MUNICIPALITY  \
# CVR
# 37427713 2017-05-30    CTYPE_APS  IND_9999   CSTAT_ACTIVE      MUN_740
# 37427713 2018-05-16    CTYPE_APS  IND_9999   CSTAT_ACTIVE      MUN_740
# 37427713 2019-05-09    CTYPE_APS  IND_9999   CSTAT_ACTIVE      MUN_740
# 37427713 2020-05-17    CTYPE_APS  IND_7022   CSTAT_ACTIVE      MUN_740
# 37427713 2021-05-28    CTYPE_APS  IND_7022   CSTAT_ACTIVE      MUN_740
# ...             ...          ...       ...            ...          ...
# 32357075 2017-06-01    CTYPE_APS  IND_6499   CSTAT_ACTIVE      MUN_101
# 32357075 2018-05-31    CTYPE_APS  IND_6499   CSTAT_ACTIVE      MUN_101
# 32357075 2019-06-03    CTYPE_APS  IND_6499   CSTAT_ACTIVE      MUN_101
# 32357075 2020-07-01    CTYPE_APS  IND_6499   CSTAT_ACTIVE      MUN_101
# 32357075 2021-07-06    CTYPE_APS  IND_6499   CSTAT_ACTIVE      MUN_101
#
#           PROFIT_LOSS    EQUITY     ASSETS  LIABILITIES  \
# CVR
# 37427713       -670.0   49330.0    49330.0          NaN
# 37427713     -28361.0   20969.0    20969.0          NaN
# 37427713       -744.0   20225.0    20225.0          NaN
# 37427713      34654.0   54879.0    58850.0       3971.0
# 37427713     -25168.0   53908.0    62611.0       8703.0
# ...               ...       ...        ...          ...
# 32357075     133919.0  291478.0  2390439.0    2098961.0
# 32357075     461197.0  592675.0  1973365.0    1380690.0
# 32357075    -374645.0 -241970.0  2265315.0    2507285.0
# 32357075     800610.0  558640.0  2761837.0    2193899.0
# 32357075     438144.0  571784.0  2292122.0    1707557.0
#
#           SHORT_TERM_LIABILITIES  CASH_AND_CASH_EQUIVALENTS  CURRENT_ASSETS
# CVR
# 37427713                     NaN                     9330.0          9330.0
# 37427713                     NaN                     9093.0          9093.0
# 37427713                     NaN                     8807.0          8807.0
# 37427713                  3971.0                    51649.0         51649.0
# 37427713                  8703.0                    62611.0         62611.0
# ...                          ...                        ...             ...
# 32357075               2098961.0                   118183.0       1633596.0
# 32357075               1380690.0                   172791.0       1236348.0
# 32357075               2507285.0                    99108.0       1608212.0
# 32357075               2193899.0                  1101024.0       1836037.0
# 32357075               1707557.0                  1240594.0       1415463.0
#
# [1573149 rows x 12 columns]

# %%
#compute number of sentences in the financials data
print("Number of sentences in the financials data: ", financials_data.shape[0])
# Out:
# Number of sentences in the financials data:  1573149

# %% [markdown]
# ### Employees

# %%
#employees path
employees_folder = DATA_ROOT / "processed" / "sources" / "employees" / "tokenized"

# %%
#read all parquet files in employees_folder
employees_data = pd.concat([pd.read_parquet(file) for file in employees_folder.glob("*.parquet")])

# %%
#only keep the rows in employees_data that have a CVR number that is in CVR_list
employees_data = employees_data[employees_data.index.isin(CVR_list)]

#convert FROM_DATE to datetime
employees_data["FROM_DATE"] = pd.to_datetime(employees_data["FROM_DATE"])

#filter away rows with FROM_DATE after threshold
threshold = datetime.datetime(2022, 1, 1)
employees_data = employees_data[employees_data["FROM_DATE"] < threshold]

# %%
employees_data
# Out:
#           FROM_DATE COMPANY_TYPE  INDUSTRY COMPANY_STATUS MUNICIPALITY  \
# CVR
# 38147323 2018-01-01    CTYPE_IVS  IND_6201   CSTAT_ACTIVE      MUN_461
# 38147323 2018-04-01    CTYPE_IVS  IND_7311   CSTAT_ACTIVE      MUN_461
# 38147323 2018-06-01    CTYPE_IVS  IND_7311   CSTAT_ACTIVE      MUN_461
# 38147323 2018-07-01    CTYPE_IVS  IND_7311   CSTAT_ACTIVE      MUN_461
# 38147323 2018-08-01    CTYPE_IVS  IND_7311   CSTAT_ACTIVE      MUN_461
# ...             ...          ...       ...            ...          ...
# 32298338 2021-08-01    CTYPE_APS  IND_7120   CSTAT_ACTIVE      MUN_707
# 32298338 2021-09-01    CTYPE_APS  IND_7120   CSTAT_ACTIVE      MUN_707
# 32298338 2021-10-01    CTYPE_APS  IND_7120   CSTAT_ACTIVE      MUN_707
# 32298338 2021-11-01    CTYPE_APS  IND_7120   CSTAT_ACTIVE      MUN_707
# 32298338 2021-12-01    CTYPE_APS  IND_7120   CSTAT_ACTIVE      MUN_707
#
#           EMPLOYEE_COUNT
# CVR
# 38147323               1
# 38147323               1
# 38147323               1
# 38147323               1
# 38147323               1
# ...                  ...
# 32298338               1
# 32298338               1
# 32298338               1
# 32298338               1
# 32298338               1
#
# [5923637 rows x 6 columns]

# %%
#compute number of sentences in the employees data
print("Number of sentences in the employees data: ", employees_data.shape[0])
# Out:
# Number of sentences in the employees data:  5923637

# %% [markdown]
# ## Count tokens

# %% [markdown]
# #### Industry

# %%
#combine lists of INDUSTRY column from employees, financials, ownership, and punit data to find industry tokens
industry_tokens = employees_data["INDUSTRY"].tolist() + financials_data["INDUSTRY"].tolist() + ownership_data["INDUSTRY"].tolist() + punit_data["INDUSTRY"].tolist()

#find unique industry tokens
industry_tokens = list(dict.fromkeys(industry_tokens))

# %%
industry_tokens
# Out:
# ['IND_6201',
#  'IND_7311',
#  'IND_8623',
#  'IND_3250',
#  'IND_8299',
#  'IND_3315',
#  'IND_7112',
#  'IND_8720',
#  'IND_7810',
#  'IND_9609',
#  'IND_3109',
#  'IND_6202',
#  'IND_4391',
#  'IND_5320',
#  'IND_4779',
#  'IND_4332',
#  'IND_5814',
#  'IND_4771',
#  'IND_0149',
#  'IND_4729',
#  'IND_4642',
#  'IND_8220',
#  'IND_5210',
#  'IND_6831',
#  'IND_4333',
#  'IND_7219',
#  'IND_7490',
#  'IND_5911',
#  'IND_4334',
#  'IND_4941',
#  'IND_4743',
#  'IND_5510',
#  'IND_4741',
#  'IND_2899',
#  'IND_0111',
#  'IND_5610',
#  'IND_4611',
#  'IND_4648',
#  'IND_7410',
#  'IND_7111',
#  'IND_2740',
#  'IND_4791',
#  'IND_7021',
#  'IND_7022',
#  'IND_7820',
#  'IND_8121',
#  'IND_8129',
#  'IND_6499',
#  'IND_4711',
#  'IND_4671',
#  'IND_5630',
#  'IND_7420',
#  'IND_9319',
#  'IND_4742',
#  'IND_6420',
#  'IND_7430',
#  'IND_7732',
#  'IND_8122',
#  'IND_7729',
#  'IND_4520',
#  'IND_7990',
#  'IND_6311',
#  'IND_9001',
#  'IND_1032',
#  'IND_9601',
#  'IND_4322',
#  'IND_4638',
#  'IND_4531',
#  'IND_2829',
#  'IND_2410',
#  'IND_9602',
#  'IND_9313',
#  'IND_4939',
#  'IND_4615',
#  'IND_4399',
#  'IND_4942',
#  'IND_6920',
#  'IND_4312',
#  'IND_4321',
#  'IND_6312',
#  'IND_8211',
#  'IND_4622',
#  'IND_2550',
#  'IND_3230',
#  'IND_4776',
#  'IND_4761',
#  'IND_5811',
#  'IND_6910',
#  'IND_9999',
#  'IND_7211',
#  'IND_5913',
#  'IND_5920',
#  'IND_0220',
#  'IND_9529',
#  'IND_4646',
#  'IND_6820',
#  'IND_8551',
#  'IND_4759',
#  'IND_4782',
#  'IND_4212',
#  'IND_3312',
#  'IND_6810',
#  'IND_4649',
#  'IND_3299',
#  'IND_8790',
#  'IND_3514',
#  'IND_3311',
#  'IND_4778',
#  'IND_9329',
#  'IND_4110',
#  'IND_1629',
#  'IND_4665',
#  'IND_4674',
#  'IND_4619',
#  'IND_9200',
#  'IND_4673',
#  'IND_5629',
#  'IND_2640',
#  'IND_4781',
#  'IND_4669',
#  'IND_6209',
#  'IND_0311',
#  'IND_9525',
#  'IND_8899',
#  'IND_6430',
#  'IND_8110',
#  'IND_6619',
#  'IND_2011',
#  'IND_5829',
#  'IND_4932',
#  'IND_4721',
#  'IND_1392',
#  'IND_4311',
#  'IND_4645',
#  'IND_4511',
#  'IND_5010',
#  'IND_4339',
#  'IND_3316',
#  'IND_4690',
#  'IND_4799',
#  'IND_4120',
#  'IND_0113',
#  'IND_6629',
#  'IND_8622',
#  'IND_4724',
#  'IND_6832',
#  'IND_7911',
#  'IND_0910',
#  'IND_9002',
#  'IND_1419',
#  'IND_4652',
#  'IND_8621',
#  'IND_3101',
#  'IND_4641',
#  'IND_4329',
#  'IND_8010',
#  'IND_8810',
#  'IND_7711',
#  'IND_8559',
#  'IND_4765',
#  'IND_2822',
#  'IND_4722',
#  'IND_6120',
#  'IND_8690',
#  'IND_1061',
#  'IND_3320',
#  'IND_7830',
#  'IND_5821',
#  'IND_1101',
#  'IND_3511',
#  'IND_4616',
#  'IND_4677',
#  'IND_4764',
#  'IND_2120',
#  'IND_1413',
#  'IND_0162',
#  'IND_7010',
#  'IND_9321',
#  'IND_5621',
#  'IND_2511',
#  'IND_1621',
#  'IND_1623',
#  'IND_2651',
#  'IND_4662',
#  'IND_0161',
#  'IND_9522',
#  'IND_2825',
#  'IND_4725',
#  'IND_4752',
#  'IND_4631',
#  'IND_4777',
#  'IND_6203',
#  'IND_8610',
#  'IND_8291',
#  'IND_4647',
#  'IND_5030',
#  'IND_3212',
#  'IND_3521',
#  'IND_3240',
#  'IND_4618',
#  'IND_1105',
#  'IND_0322',
#  'IND_2790',
#  'IND_6622',
#  'IND_9003',
#  'IND_7120',
#  'IND_4613',
#  'IND_4637',
#  'IND_4636',
#  'IND_1082',
#  'IND_8130',
#  'IND_5819',
#  'IND_4639',
#  'IND_4775',
#  'IND_1085',
#  'IND_0128',
#  'IND_1071',
#  'IND_2893',
#  'IND_8020',
#  'IND_4634',
#  'IND_6492',
#  'IND_2562',
#  'IND_2561',
#  'IND_0150',
#  'IND_4661',
#  'IND_6190',
#  'IND_0142',
#  'IND_8030',
#  'IND_9312',
#  'IND_3832',
#  'IND_9004',
#  'IND_4651',
#  'IND_4299',
#  'IND_4614',
#  'IND_8891',
#  'IND_0812',
#  'IND_4666',
#  'IND_6399',
#  'IND_4540',
#  'IND_0240',
#  'IND_3012',
#  'IND_3700',
#  'IND_7500',
#  'IND_1330',
#  'IND_4633',
#  'IND_1107',
#  'IND_1812',
#  'IND_4532',
#  'IND_1610',
#  'IND_2059',
#  'IND_2821',
#  'IND_4772',
#  'IND_9604',
#  'IND_3314',
#  'IND_7739',
#  'IND_9311',
#  'IND_4643',
#  'IND_1011',
#  'IND_6391',
#  'IND_2223',
#  'IND_4644',
#  'IND_9512',
#  'IND_2399',
#  'IND_5221',
#  'IND_6010',
#  'IND_8552',
#  'IND_5530',
#  'IND_0210',
#  'IND_9521',
#  'IND_8553',
#  'IND_4774',
#  'IND_1089',
#  'IND_4632',
#  'IND_5520',
#  'IND_5222',
#  'IND_4519',
#  'IND_3213',
#  'IND_0143',
#  'IND_2341',
#  'IND_2612',
#  'IND_8230',
#  'IND_6630',
#  'IND_9102',
#  'IND_7320',
#  'IND_0141',
#  'IND_4754',
#  'IND_2573',
#  'IND_0147',
#  'IND_4211',
#  'IND_0129',
#  'IND_1052',
#  'IND_4672',
#  'IND_2811',
#  'IND_2572',
#  'IND_2920',
#  'IND_5229',
#  'IND_1020',
#  'IND_3530',
#  'IND_6612',
#  'IND_4723',
#  'IND_4789',
#  'IND_1813',
#  'IND_2361',
#  'IND_4623',
#  'IND_9511',
#  'IND_7312',
#  'IND_4663',
#  'IND_2910',
#  'IND_7721',
#  'IND_7734',
#  'IND_0146',
#  'IND_2660',
#  'IND_4675',
#  'IND_2670',
#  'IND_7912',
#  'IND_4730',
#  'IND_3220',
#  'IND_8219',
#  'IND_2896',
#  'IND_4222',
#  'IND_4676',
#  'IND_1393',
#  'IND_8520',
#  'IND_0163',
#  'IND_1729',
#  'IND_4726',
#  'IND_1083',
#  'IND_8560',
#  'IND_5020',
#  'IND_1039',
#  'IND_4753',
#  'IND_3092',
#  '[UNK]',
#  'IND_8531',
#  'IND_2453',
#  'IND_5912',
#  'IND_4621',
#  'IND_1721',
#  'IND_9603',
#  'IND_2599',
#  'IND_9524',
#  'IND_2042',
#  'IND_2593',
#  'IND_0125',
#  'IND_2932',
#  'IND_2030',
#  'IND_2892',
#  'IND_2222',
#  'IND_2849',
#  'IND_2370',
#  'IND_4931',
#  'IND_3811',
#  'IND_2620',
#  'IND_2229',
#  'IND_4719',
#  'IND_4291',
#  'IND_8532',
#  'IND_1512',
#  'IND_6512',
#  'IND_2363',
#  'IND_4220',
#  'IND_2841',
#  'IND_1092',
#  'IND_5224',
#  'IND_8292',
#  'IND_4290',
#  'IND_4221',
#  'IND_2512',
#  'IND_4612',
#  'IND_8541',
#  'IND_8710',
#  'IND_1814',
#  'IND_1013',
#  'IND_3513',
#  'IND_6530',
#  'IND_4210',
#  'IND_1712',
#  'IND_1084',
#  'IND_8730',
#  'IND_1724',
#  'IND_7712',
#  'IND_2813',
#  'IND_7740',
#  'IND_3103',
#  'IND_9499',
#  'IND_3900',
#  'IND_3102',
#  'IND_6020',
#  'IND_8422',
#  'IND_6110',
#  'IND_8413',
#  'IND_1394',
#  'IND_0119',
#  'IND_1820',
#  'IND_1399',
#  'IND_4664',
#  'IND_5223',
#  'IND_5914',
#  'IND_2221',
#  'IND_2611',
#  'IND_1412',
#  'IND_3313',
#  'IND_3831',
#  'IND_8412',
#  'IND_2630',
#  'IND_2442',
#  'IND_7733',
#  'IND_2712',
#  'IND_2110',
#  'IND_9523',
#  'IND_0164',
#  'IND_5813',
#  'IND_2041',
#  'IND_4751',
#  'IND_2219',
#  'IND_1520',
#  'IND_6511',
#  'IND_2312',
#  'IND_2443',
#  'IND_4213',
#  'IND_1722',
#  'IND_0892',
#  'IND_1624',
#  'IND_2830',
#  'IND_4617',
#  'IND_6491',
#  'IND_3821',
#  'IND_2365',
#  'IND_1622',
#  'IND_2314',
#  'IND_2529',
#  'IND_2332',
#  'IND_0130',
#  'IND_1081',
#  'IND_1051',
#  'IND_1091',
#  'IND_2733',
#  'IND_2591',
#  'IND_7722',
#  'IND_2013',
#  'IND_2814',
#  'IND_2815',
#  'IND_2016',
#  'IND_2751',
#  'IND_1414',
#  'IND_2369',
#  'IND_2812',
#  'IND_2364',
#  'IND_1723',
#  'IND_7020',
#  'IND_0610',
#  'IND_6621',
#  'IND_1391',
#  'IND_2711',
#  'IND_2571',
#  'IND_1439',
#  'IND_4763',
#  'IND_2732',
#  'IND_2052',
#  'IND_3030',
#  'IND_2894',
#  'IND_4910',
#  'IND_0893',
#  'IND_3110',
#  'IND_2391',
#  'IND_3522',
#  'IND_2652',
#  'IND_0124',
#  'IND_9420',
#  'IND_1920',
#  'IND_2020',
#  'IND_1320',
#  'IND_2594',
#  'IND_2420',
#  'IND_4624',
#  'IND_3600',
#  'IND_1012',
#  'IND_1310',
#  'IND_2540',
#  'IND_2433',
#  'IND_3319',
#  'IND_1102',
#  'IND_5812',
#  'IND_2319',
#  'IND_1420',
#  'IND_2320',
#  'IND_0811',
#  'IND_2731',
#  'IND_2349',
#  'IND_3099',
#  'IND_2311',
#  'IND_3011',
#  'IND_1042',
#  'IND_6611',
#  'IND_1396',
#  'IND_2521',
#  'IND_9101',
#  'IND_1031',
#  'IND_3091',
#  'IND_1041',
#  'IND_2891',
#  'IND_3020',
#  'IND_5110',
#  'IND_1200',
#  'IND_7731',
#  'IND_7220',
#  'IND_1072',
#  'IND_2895',
#  'IND_2342',
#  'IND_7735',
#  'IND_4762',
#  'IND_2313',
#  'IND_5040',
#  'IND_2012',
#  'IND_6130',
#  'IND_2592',
#  'IND_2824',
#  'IND_6419',
#  'IND_0116',
#  'IND_0990',
#  'IND_4635',
#  'IND_2451',
#  'IND_1103',
#  'IND_1086',
#  'IND_0321',
#  'IND_4331',
#  'IND_2720',
#  'IND_0170',
#  'IND_1395',
#  'IND_2530',
#  'IND_3291',
#  'IND_2454',
#  'IND_2211',
#  'IND_9104',
#  'IND_2051',
#  'IND_2444',
#  'IND_2343',
#  'IND_1811',
#  'IND_1431',
#  'IND_4920',
#  'IND_9412',
#  'IND_5590',
#  'IND_9411',
#  'IND_0620',
#  'IND_3523',
#  'IND_3512',
#  'IND_5122',
#  'IND_7222',
#  'IND_1104',
#  'IND_2344',
#  'IND_1511',
#  'IND_8542',
#  'IND_0121',
#  'IND_5121',
#  'IND_0899',
#  'IND_2752',
#  'IND_2931',
#  'IND_2351',
#  'IND_0145',
#  'IND_1106',
#  'IND_8411',
#  'IND_0312',
#  'IND_3317',
#  'IND_1411',
#  'IND_2053',
#  'IND_2060',
#  'IND_3040',
#  'IND_9103',
#  'IND_1073',
#  'IND_9700',
#  'IND_3822',
#  'IND_3812',
#  'IND_4773',
#  'IND_8513',
#  'IND_8425',
#  'IND_4313',
#  'IND_9800',
#  'IND_7414',
#  'IND_2452',
#  'IND_2431',
#  'IND_4533',
#  'IND_2014',
#  'IND_2015',
#  'IND_2875',
#  'IND_2823',
#  'IND_2441',
#  'IND_2331',
#  'IND_5143',
#  'IND_2680',
#  'IND_2432',
#  'IND_5310',
#  'IND_0230',
#  'IND_1062',
#  'IND_0127',
#  'IND_4950',
#  'IND_8421',
#  'IND_2362',
#  'IND_8510',
#  'IND_0729',
#  'IND_6520',
#  'IND_7411',
#  'IND_6523',
#  'IND_5153',
#  'IND_2352',
#  'IND_5135',
#  'IND_5211',
#  'IND_5182',
#  'IND_5142',
#  'IND_7484',
#  'IND_5242',
#  'IND_5164',
#  'IND_5247',
#  'IND_1587',
#  'IND_2122',
#  'IND_6720',
#  'IND_5244',
#  'IND_2852',
#  'IND_4521',
#  'IND_7470',
#  'IND_2524',
#  'IND_5156',
#  'IND_5154',
#  'IND_5245',
#  'IND_5146',
#  'IND_5248',
#  'IND_5511',
#  'IND_4542',
#  'IND_5246',
#  'IND_2121',
#  'IND_5166',
#  'IND_5551',
#  'IND_8512',
#  'IND_7031',
#  'IND_7415',
#  'IND_0502',
#  'IND_2851',
#  'IND_5241',
#  'IND_8514',
#  'IND_3550',
#  'IND_7481',
#  'IND_5243',
#  'IND_2462',
#  'IND_4525',
#  'IND_5147',
#  'IND_2956',
#  'IND_1596',
#  'IND_6340',
#  'IND_3611',
#  'IND_2040',
#  'IND_2125',
#  'IND_6522',
#  'IND_2940',
#  'IND_6521',
#  'IND_4544',
#  'IND_2923',
#  'IND_7412',
#  'IND_1589',
#  'IND_5161',
#  'IND_9261',
#  'IND_5144',
#  'IND_5157',
#  'IND_0112',
#  'IND_5163',
#  'IND_3150',
#  'IND_7440',
#  'IND_3622',
#  'IND_3614',
#  'IND_4545',
#  'IND_5050',
#  'IND_2953',
#  'IND_2414',
#  'IND_5132',
#  'IND_1421',
#  'IND_2922',
#  'IND_5131',
#  'IND_7110',
#  'IND_2722',
#  'IND_6024',
#  'IND_7134',
#  'IND_5165',
#  'IND_7121',
#  'IND_5151',
#  'IND_9000',
#  'IND_5170',
#  'IND_3310',
#  'IND_5119',
#  'IND_7132',
#  'IND_5115',
#  'IND_7450',
#  'IND_5145',
#  'IND_5141',
#  'IND_2212',
#  'IND_2753',
#  'IND_7140',
#  'IND_7483',
#  'IND_2661',
#  'IND_3120',
#  'IND_2623',
#  'IND_2874',
#  'IND_2522',
#  'IND_5152',
#  'IND_9303',
#  'IND_2213',
#  'IND_1822',
#  'IND_2913',
#  'IND_9272',
#  'IND_1586',
#  'IND_1533',
#  'IND_3162',
#  'IND_6210',
#  'IND_3430',
#  'IND_7133',
#  'IND_5226',
#  'IND_5233',
#  'IND_3420',
#  'IND_5540',
#  'IND_5185',
#  'IND_2224',
#  'IND_3612',
#  'IND_2742',
#  'IND_2430',
#  'IND_2112',
#  'IND_9211',
#  'IND_7032',
#  'IND_5114',
#  'IND_2924',
#  'IND_2215',
#  'IND_5155',
#  'IND_1572',
#  'IND_5138',
#  'IND_5225',
#  'IND_2862',
#  'IND_5124',
#  'IND_5184',
#  'IND_7230',
#  'IND_2912',
#  'IND_9240',
#  'IND_4522',
#  'IND_2523',
#  'IND_5118',
#  'IND_5134',
#  'IND_3613',
#  'IND_5188',
#  'IND_5136',
#  'IND_6330',
#  'IND_3663',
#  'IND_1581',
#  'IND_0201',
#  'IND_6030',
#  'IND_5162',
#  'IND_1561',
#  'IND_6021',
#  'IND_3630',
#  'IND_5111',
#  'IND_7260',
#  'IND_7487',
#  'IND_8042',
#  'IND_6322',
#  'IND_5190',
#  'IND_8511',
#  'IND_3720',
#  'IND_9262',
#  'IND_0123',
#  'IND_2416',
#  'IND_5273',
#  'IND_1771',
#  'IND_2873',
#  'IND_2664',
#  'IND_8022',
#  'IND_2914',
#  'IND_1110',
#  'IND_1120',
#  'IND_4550',
#  'IND_1760',
#  'IND_4030',
#  'IND_5212',
#  'IND_9231',
#  'IND_7310',
#  'IND_5552',
#  'IND_7413',
#  'IND_7210',
#  'IND_7240',
#  'IND_1551',
#  'IND_9305',
#  'IND_9302',
#  'IND_5271',
#  'IND_9301',
#  'IND_3543',
#  'IND_5139',
#  'IND_9304',
#  'IND_6411',
#  'IND_5521',
#  'IND_1571',
#  'IND_4010',
#  'IND_8041',
#  'IND_7012',
#  'IND_7485',
#  'IND_1720',
#  'IND_2735',
#  'IND_5116',
#  'IND_1513',
#  'IND_1740',
#  'IND_5227',
#  'IND_2971',
#  'IND_5250',
#  'IND_7460',
#  'IND_9271',
#  'IND_1532',
#  'IND_2942',
#  'IND_5137',
#  'IND_4543',
#  'IND_4021',
#  'IND_5187',
#  'IND_7221',
#  'IND_5274',
#  'IND_9220',
#  'IND_6713',
#  'IND_4022',
#  'IND_5181',
#  'IND_9500',
#  'IND_5261',
#  'IND_2010',
#  'IND_2614',
#  'IND_5263',
#  'IND_1584',
#  'IND_4013',
#  'IND_2663',
#  'IND_2214',
#  'IND_3330',
#  'IND_3542',
#  'IND_6023',
#  'IND_5186',
#  'IND_5112',
#  'IND_7122',
#  'IND_2461',
#  'IND_0202',
#  'IND_7123',
#  'IND_4011',
#  'IND_1730',
#  'IND_1582',
#  'IND_0122',
#  'IND_2465',
#  'IND_5133',
#  'IND_3130',
#  'IND_5272',
#  'IND_3002',
#  'IND_0501',
#  'IND_6412',
#  'IND_1772',
#  'IND_2681',
#  'IND_2721',
#  'IND_6712',
#  'IND_1598',
#  'IND_2745',
#  'IND_9120',
#  'IND_5232',
#  'IND_7011',
#  'IND_9252',
#  'IND_2972',
#  'IND_7250',
#  'IND_7486',
#  'IND_6603',
#  'IND_6220',
#  'IND_7514',
#  'IND_3140',
#  'IND_2840',
#  'IND_5262',
#  'IND_5113',
#  'IND_5123',
#  'IND_5523',
#  'IND_1531',
#  'IND_7131',
#  'IND_5522',
#  'IND_1930',
#  'IND_1752',
#  'IND_3210',
#  'IND_2123',
#  'IND_9213',
#  'IND_2954',
#  'IND_1751',
#  'IND_9232',
#  'IND_2921',
#  'IND_2861',
#  'IND_2710',
#  'IND_1824',
#  'IND_9234',
#  'IND_9212',
#  'IND_3650',
#  'IND_1583',
#  'IND_9111',
#  'IND_2413',
#  'IND_4100',
#  'IND_2952',
#  'IND_2621',
#  'IND_2232',
#  'IND_7482',
#  'IND_2871',
#  'IND_2233',
#  'IND_3161',
#  'IND_1600',
#  'IND_2415',
#  'IND_2470',
#  'IND_2622',
#  'IND_5512',
#  'IND_5117',
#  'IND_2225',
#  'IND_3615',
#  'IND_2231',
#  'IND_4020',
#  'IND_6601',
#  'IND_2682',
#  'IND_2513',
#  'IND_1591',
#  'IND_2863',
#  'IND_9251',
#  'IND_3662',
#  'IND_3340',
#  'IND_9133',
#  'IND_1754',
#  'IND_6321',
#  'IND_1823',
#  'IND_1710',
#  'IND_2911',
#  'IND_3520',
#  'IND_0891',
#  'IND_3640',
#  'IND_1821',
#  'IND_2466',
#  'IND_6323',
#  'IND_7525',
#  'IND_2666',
#  'IND_2625',
#  'IND_2124']

# %%
len(industry_tokens)
# Out:
# 933

# %% [markdown]
# #### Status

# %%
#combine lists of STATUS column from employees, financials and status data to find status tokens
status_tokens = employees_data["COMPANY_STATUS"].tolist() + financials_data["COMPANY_STATUS"].tolist() + status_data["COMPANY_STATUS"].tolist()

#find unique status tokens
status_tokens = list(dict.fromkeys(status_tokens))

# %%
status_tokens
# Out:
# ['CSTAT_ACTIVE',
#  'CSTAT_ONGOING_DISSOLUTION',
#  'CSTAT_DISSOLVED_MERGER',
#  'CSTAT_ONGOING_BANKRUPTCY',
#  'CSTAT_ONGOING_LIQUIDATION',
#  'CSTAT_NO_LEGAL_EFFECT',
#  'CSTAT_DISSOLVED',
#  'CSTAT_ONGOING_RECONSTRUCTION',
#  'CSTAT_DISSOLVED_DECLARATION',
#  'CSTAT_DISSOLVED_LIQUIDATION',
#  '[UNK]',
#  'CSTAT_ONGOING_REASSUMPTION',
#  'CSTAT_DISSOLVED_MIGRATION']

# %%
len(status_tokens)-1
# Out:
# 12

# %% [markdown]
# #### Municipality

# %%
#combine lists of MUNICIPALITY column from employees, financials and punit data to find municipality tokens
municipality_tokens = employees_data["MUNICIPALITY"].tolist() + financials_data["MUNICIPALITY"].tolist() + punit_data["MUNICIPALITY"].tolist()

#find unique municipality tokens
municipality_tokens = list(dict.fromkeys(municipality_tokens))

# %%
municipality_tokens
# Out:
# ['MUN_461',
#  'MUN_175',
#  'MUN_101',
#  'MUN_740',
#  'MUN_760',
#  'MUN_561',
#  'MUN_259',
#  'MUN_350',
#  'MUN_173',
#  'MUN_773',
#  'MUN_756',
#  'MUN_250',
#  'MUN_219',
#  'MUN_540',
#  'MUN_167',
#  'MUN_657',
#  'MUN_621',
#  'MUN_851',
#  'MUN_810',
#  'MUN_201',
#  'MUN_157',
#  'MUN_217',
#  'MUN_159',
#  'MUN_751',
#  'MUN_730',
#  'MUN_727',
#  'MUN_813',
#  'MUN_153',
#  'MUN_165',
#  'MUN_163',
#  'MUN_791',
#  'MUN_376',
#  'MUN_766',
#  'MUN_846',
#  'MUN_615',
#  'MUN_147',
#  'MUN_169',
#  'MUN_410',
#  'MUN_330',
#  'MUN_630',
#  'MUN_746',
#  'MUN_270',
#  'MUN_450',
#  'MUN_230',
#  'MUN_210',
#  'MUN_661',
#  'MUN_151',
#  'MUN_707',
#  'MUN_240',
#  'MUN_820',
#  'MUN_607',
#  'MUN_336',
#  'MUN_316',
#  'MUN_340',
#  'MUN_573',
#  'MUN_320',
#  'MUN_265',
#  'MUN_482',
#  'MUN_420',
#  'MUN_253',
#  'MUN_510',
#  'MUN_779',
#  'MUN_492',
#  'MUN_710',
#  'MUN_706',
#  'MUN_190',
#  'MUN_183',
#  'MUN_479',
#  'MUN_860',
#  'MUN_430',
#  'MUN_370',
#  'MUN_161',
#  'MUN_400',
#  'MUN_269',
#  'MUN_840',
#  'MUN_665',
#  'MUN_187',
#  'MUN_223',
#  'MUN_260',
#  'MUN_390',
#  'MUN_787',
#  'MUN_849',
#  'MUN_306',
#  'MUN_440',
#  'MUN_580',
#  'MUN_155',
#  'MUN_741',
#  'MUN_329',
#  'MUN_360',
#  'MUN_326',
#  'MUN_185',
#  'MUN_530',
#  'MUN_575',
#  'MUN_550',
#  'MUN_480',
#  'MUN_563',
#  'MUN_671',
#  'MUN_825',
#  '[UNK]',
#  'MUN_565',
#  'MUN_745',
#  'MUN_956',
#  'MUN_957',
#  'MUN_411',
#  'MUN_960',
#  'MUN_955',
#  'MUN_959',
#  'MUN_845',
#  'MUN_789',
#  'MUN_631',
#  'MUN_537',
#  'MUN_385',
#  'MUN_603',
#  'MUN_357',
#  'MUN_515',
#  'MUN_391',
#  'MUN_373',
#  'MUN_449',
#  'MUN_861',
#  'MUN_667',
#  'MUN_445',
#  'MUN_517',
#  'MUN_427',
#  'MUN_205',
#  'MUN_307',
#  'MUN_331',
#  'MUN_731',
#  'MUN_323',
#  'MUN_181',
#  'MUN_441',
#  'MUN_208',
#  'MUN_625',
#  'MUN_793',
#  'MUN_545',
#  'MUN_701',
#  'MUN_651',
#  'MUN_685',
#  'MUN_315',
#  'MUN_333',
#  'MUN_335',
#  'MUN_519',
#  'MUN_611',
#  'MUN_771',
#  'MUN_489',
#  'MUN_447',
#  'MUN_703',
#  'MUN_369',
#  'MUN_777',
#  'MUN_207',
#  'MUN_531',
#  'MUN_833',
#  'MUN_171',
#  'MUN_663',
#  'MUN_473',
#  'MUN_367',
#  'MUN_351',
#  'MUN_227',
#  'MUN_327',
#  'MUN_619',
#  'MUN_305',
#  'MUN_189',
#  'MUN_233',
#  'MUN_503',
#  'MUN_743',
#  'MUN_571',
#  'MUN_403',
#  'MUN_505',
#  'MUN_543',
#  'MUN_209',
#  'MUN_627',
#  'MUN_653',
#  'MUN_421',
#  'MUN_555',
#  'MUN_769',
#  'MUN_497',
#  'MUN_229',
#  'MUN_683',
#  'MUN_721',
#  'MUN_395',
#  'MUN_709',
#  'MUN_431',
#  'MUN_363',
#  'MUN_605',
#  'MUN_569',
#  'MUN_361',
#  'MUN_213',
#  'MUN_827',
#  'MUN_847',
#  'MUN_365',
#  'MUN_409',
#  'MUN_475',
#  'MUN_235',
#  'MUN_383',
#  'MUN_669',
#  'MUN_325',
#  'MUN_211',
#  'MUN_725',
#  'MUN_393',
#  'MUN_541',
#  'MUN_711',
#  'MUN_737',
#  'MUN_613',
#  'MUN_511',
#  'MUN_629',
#  'MUN_815',
#  'MUN_823',
#  'MUN_821',
#  'MUN_767',
#  'MUN_521',
#  'MUN_471',
#  'MUN_841',
#  'MUN_313',
#  'MUN_807',
#  'MUN_493',
#  'MUN_341',
#  'MUN_237',
#  'MUN_557',
#  'MUN_371',
#  'MUN_655',
#  'MUN_523',
#  'MUN_733',
#  'MUN_747',
#  'MUN_817',
#  'MUN_495',
#  'MUN_343',
#  'MUN_761',
#  'MUN_601',
#  'MUN_483',
#  'MUN_261',
#  'MUN_345',
#  'MUN_539',
#  'MUN_805',
#  'MUN_729',
#  'MUN_339',
#  'MUN_739',
#  'MUN_215',
#  'MUN_303',
#  'MUN_407',
#  'MUN_405',
#  'MUN_719',
#  'MUN_263',
#  'MUN_623',
#  'MUN_749',
#  'MUN_429',
#  'MUN_477',
#  'MUN_681',
#  'MUN_677',
#  'MUN_397',
#  'MUN_525',
#  'MUN_559',
#  'MUN_577',
#  'MUN_553',
#  'MUN_221',
#  'MUN_509',
#  'MUN_819',
#  'MUN_499',
#  'MUN_529',
#  'MUN_527',
#  'MUN_735',
#  'MUN_485',
#  'MUN_831',
#  'MUN_723',
#  'MUN_705',
#  'MUN_389',
#  'MUN_551',
#  'MUN_513',
#  'MUN_835',
#  'MUN_255',
#  'MUN_809',
#  'MUN_763',
#  'MUN_713',
#  'MUN_781',
#  'MUN_451',
#  'MUN_375',
#  'MUN_437',
#  'MUN_267',
#  'MUN_377',
#  'MUN_811',
#  'MUN_837',
#  'MUN_803',
#  'MUN_271',
#  'MUN_231',
#  'MUN_765',
#  'MUN_425',
#  'MUN_659',
#  'MUN_609',
#  'MUN_387',
#  'MUN_801',
#  'MUN_715',
#  'MUN_507',
#  'MUN_487',
#  'MUN_567',
#  'MUN_491',
#  'MUN_443',
#  'MUN_309',
#  'MUN_775',
#  'MUN_353',
#  'MUN_257',
#  'MUN_717',
#  'MUN_401',
#  'MUN_439',
#  'MUN_301',
#  'MUN_785',
#  'MUN_829',
#  'MUN_843',
#  'MUN_675',
#  'MUN_535',
#  'MUN_319',
#  'MUN_433',
#  'MUN_251',
#  'MUN_839',
#  'MUN_311',
#  'MUN_359',
#  'MUN_225',
#  'MUN_435',
#  'MUN_783',
#  'MUN_423',
#  'MUN_673',
#  'MUN_679',
#  'MUN_355',
#  'MUN_321',
#  'MUN_617',
#  'MUN_379',
#  'MUN_337',
#  'MUN_317',
#  'MUN_533',
#  'MUN_961',
#  'MUN_501',
#  'MUN_381',
#  'MUN_481']

# %%
len(municipality_tokens)-1
# Out:
# 329

# %% [markdown]
# ## Global set sequence length analysis

# %%
global_data['LENGTH'] = global_data["SENTENCE"].apply(lambda x: len(x.split()))

# %%
global_data
# Out:
#           FROM_DATE                                           SENTENCE  \
# CVR
# 40975470       2521                          ACT_OPEN IND_7732 MUN_370
# 40975470       2521                                       CSTAT_ACTIVE
# 40975470       2555                       LEADER_DIRECTOR EXPERIENCE_3
# 40975470       2769  CTYPE_APS IND_7732 CSTAT_ACTIVE MUN_340 EMPLOY...
# 40975470       2800  CTYPE_APS IND_7732 CSTAT_ACTIVE MUN_340 EMPLOY...
# ...             ...                                                ...
# 33920717       3195  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3220  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 PROFIT_...
# 33920717       3226  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3256  CTYPE_AS IND_1610 CSTAT_ACTIVE MUN_575 EMPLOYE...
# 33920717       3286   LEADER_BOARD EXPERIENCE_3 LEADER_CEO EXPERIEN...
#
#          FOUNDING_DATE  AFTER_THRESHOLD   AGE  LENGTH
# CVR
# 40975470    2019-11-27            False   0.0       3
# 40975470    2019-11-27            False   0.0       1
# 40975470    2019-11-27            False  -1.0       2
# 40975470    2019-11-27            False   0.0       5
# 40975470    2019-11-27            False   0.0       5
# ...                ...              ...   ...     ...
# 33920717    1971-03-05            False  50.0       5
# 33920717    1971-03-05            False  50.0      11
# 33920717    1971-03-05            False  50.0       5
# 33920717    1971-03-05            False  50.0       5
# 33920717    1971-03-05            False  49.0      12
#
# [10194841 rows x 6 columns]

# %%
seqlen = global_data.groupby("CVR")["LENGTH"].sum()

# %%
#plot histogram of sentence lengths
plt.figure(figsize=(12, 6))
sns.histplot(seqlen, bins=1000, color="lightslategray", edgecolor='white')
plt.title("Sequence Length Distribution")
plt.xlabel("Sequence length")
plt.ylabel("Counts")

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Add vertical line at 2560
ax.axvline(2560, color="blue", linewidth=1, linestyle=":", label="Sequence length cutoff")
plt.legend()

# %%
#plot boxplot of sequence lengths
plt.figure(figsize=(6, 6))
sns.boxplot(seqlen.values, color="lightslategray")
plt.title("Boxplot of Sequence Lengths")
plt.ylabel("Sequence length")

ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# Add vertical line at 2560
ax.axhline(2560, color="blue", linewidth=1, linestyle=":", label="Sequence length cutoff")
plt.legend()

# %% [markdown]
# ## Vocab size

# %%
# load final tokens
final_tokens = pd.read_csv(DATA_ROOT / "processed" / "vocab" / "global_set" / "result.tsv", sep="\t")

# %%
final_tokens
# Out:
#       ID                      TOKEN CATEGORY
# 0      0                      [PAD]  GENERAL
# 1      1                      [CLS]  GENERAL
# 2      2                      [SEP]  GENERAL
# 3      3                     [MASK]  GENERAL
# 4      4                    [PLCH0]  GENERAL
# ..   ...                        ...      ...
# 988  988  SHORT_TERM_LIABILITIES_94    SHORT
# 989  989  SHORT_TERM_LIABILITIES_95    SHORT
# 990  990  SHORT_TERM_LIABILITIES_96    SHORT
# 991  991  SHORT_TERM_LIABILITIES_97    SHORT
# 992  992  SHORT_TERM_LIABILITIES_98    SHORT
#
# [993 rows x 3 columns]

# %%
print("Number of unique tokens in the global training set: ", final_tokens.shape[0])
# Out:
# Number of unique tokens in the global training set:  993

# %%
final_tokens.CATEGORY.value_counts()
# Out:
# IND            118
# EQUITY          98
# CURRENT         97
# LIABILITIES     97
# SHORT           97
# ASSETS          97
# PROFIT          96
# CASH            95
# MUN             93
# EMPLOYEES       35
# EXPERIENCE      14
# GENERAL         10
# CSTAT            9
# INV              8
# SHARE            7
# RATE             6
# PAY              5
# LEADER           4
# CTYPE            3
# ACT              2
# OTYP             2
# Name: CATEGORY, dtype: int64

# %%
#find the cstat tokens
final_tokens[final_tokens["CATEGORY"] == "CSTAT"]["TOKEN"]
# Out:
# 204                   CSTAT_ACTIVE
# 205                CSTAT_DISSOLVED
# 206    CSTAT_DISSOLVED_DECLARATION
# 207    CSTAT_DISSOLVED_LIQUIDATION
# 208         CSTAT_DISSOLVED_MERGER
# 209          CSTAT_NO_LEGAL_EFFECT
# 210       CSTAT_ONGOING_BANKRUPTCY
# 211      CSTAT_ONGOING_DISSOLUTION
# 212      CSTAT_ONGOING_LIQUIDATION
# Name: TOKEN, dtype: object
